# %% [markdown]
# # DCGAN on Oxford 102 Flower

# %% [markdown]
# In this notebook we train a Deep Convolutional GAN (DCGAN) on Oxford 102 Flower dataset. This datasets consists of 102 flower classes, each containing between 40 and 256 instances. We leverage data augmentation to increase the size of the dataset and reduce overfitting.

# %% [markdown]
# ## 1. Background

# %% [markdown]
# Historically, DCGAN represents significant progress in developing more scalable GAN architectures. The authors adopt three changes to the standard CNN architecture and show that these allow for stable training on higher resolution images.
#
# 1. Replace deterministic pooling functions (e.g. max pooling) with learned downsampling/upsampling layers (e.g. strided convolutions).
#
# 2. Remove dense layers after convolutional stacks.
#
# 3. Use batch normalization in order to stabalize training, reduce the influence of poor initialization and improve gradient flow. In the context of GANs, batch normalization has shown to be effective in reducing mode collapse. To prevent perpetual oscilation between the generator and discriminator however, the authors do not apply batch normalization to either the generator output or discriminator input.
#
# ![](https://i.ibb.co/0jc930m/Capture.png)
#
# The authors specifically use the following architecture for their generator.
#
# ![](https://i.ibb.co/YPhrm08/Capture.png)

# %% [markdown]
# ## 2. Implementation

# %% [markdown]
# ### 2.1. Setup

# %%
#@markdown

from typing import TypeAlias, Any, Callable, Tuple, List
from dataclasses import dataclass

import os
import sys
import tempfile
import time
import math
import random

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.distributed as dist
import torch.multiprocessing as mp
from torch.nn.parallel import DistributedDataParallel as DDP
from torch.utils.data import DataLoader, Dataset, ConcatDataset
from torch.optim import SGD, Adam

from torchvision.transforms import (
    Compose,
    Normalize,
    Resize,
    RandomCrop,
    RandomRotation,
    RandomHorizontalFlip,
    RandomVerticalFlip,
    ColorJitter,
    ToTensor,
    PILToTensor,
    ToPILImage,

)

from torchvision.datasets import Flowers102
from torch.utils.data import DataLoader
from torchvision.utils import save_image

import pandas as pd
import seaborn as sns

# %%
#@markdown

EPOCHS = 300
BATCH_SIZE = 128

IMAGE_WIDTH  = 64
IMAGE_HEIGHT = 64
IMAGE_NORMALIZATION_MEAN = 0.5
IMAGE_NORMALIZATION_STANDARD_DEVIATION = 0.5

# FABRIC_RANKS = 8
# FABRIC_ACCELERATOR = 'gpu'
# FABRIC_STRATEGY = 'ddp'

LATENT_DIMENSION = 100

# %%
#@markdown

transform = Compose([
    ToTensor(),
    Resize((IMAGE_WIDTH, IMAGE_HEIGHT), interpolation=0),
    Normalize(
        mean=IMAGE_NORMALIZATION_MEAN,
        std=IMAGE_NORMALIZATION_STANDARD_DEVIATION,
    ),
])

train_dataset = Flowers102(
    root='.',
    split='train',
    transform=transform,
    download=True,
)

validation_dataset = Flowers102(
    root='.',
    split='test',
    transform=transform,
    download=True
)

dataset = ConcatDataset((train_dataset, validation_dataset))
# Out:
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/102flowers.tgz to flowers-102/102flowers.tgz
# 100%|██████████| 344862509/344862509 [00:02<00:00, 158644186.50it/s]
# Extracting flowers-102/102flowers.tgz to flowers-102
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/imagelabels.mat to flowers-102/imagelabels.mat
# 100%|██████████| 502/502 [00:00<00:00, 1471377.08it/s]
# Downloading https://thor.robots.ox.ac.uk/datasets/flowers-102/setid.mat to flowers-102/setid.mat
# 100%|██████████| 14989/14989 [00:00<00:00, 19689452.76it/s]

# %%
#@markdown

# def setup(rank, world_size):
#     os.environ['MASTER_ADDR'] = 'localhost'
#     os.environ['MASTER_PORT'] = '12355'

#     # initialize the process group
#     dist.init_process_group("gloo", rank=rank, world_size=world_size)

# def cleanup():
#     dist.destroy_process_group()

# setup(0, 1)

# %%
#@markdown

# fabric = L.Fabric(
#     accelerator=FABRIC_ACCELERATOR,
#     devices=FABRIC_RANKS,
#     strategy=FABRIC_STRATEGY,
# )

# fabric.launch()

# %%
#@markdown

# Using for instance `number_of_crops = 4`, we can obtain a dataset with many
# more images - from 7000 to 100,000.

def renormalize(x: torch.Tensor) -> torch.Tensor:
    return (x - x.min()) / (x.max() - x.min())

def get_augments(x: torch.Tensor, number_of_crops: int = 4) -> List[torch.Tensor]:

    augments = []

    random_vertical_flip = RandomVerticalFlip(p=1)
    random_horizontal_flip = RandomHorizontalFlip(p=1)
    random_crop =  RandomCrop(size=(IMAGE_WIDTH // 2, IMAGE_HEIGHT // 2))
    # random_color_jitter = ColorJitter(hue=.04)
    resize = Resize(size=(IMAGE_WIDTH, IMAGE_HEIGHT), interpolation=0)

    for _ in range(number_of_crops):
        crop = random_crop(x)
        crop = resize(crop)

        augments.append(crop)
        augments.append(random_horizontal_flip(crop))
        augments.append(random_vertical_flip(crop))

    augments.append(random_horizontal_flip(x))
    augments.append(random_vertical_flip(x))

    random.shuffle(augments)

    return augments


print('Creating augmented dataset (wait 1 minute)...')

augmented_dataset = []

for x, _ in dataset:
    augmented_dataset += get_augments(x.cuda())
# Out:
# Creating augmented dataset (wait 1 minute)...

# %% [markdown]
# ### 2.2. Models

# %%
#@markdown

generator = nn.Sequential(

    # Projection from (-1, LATENT_DIMENSION, 1, 1) to (-1, 1024, 4, 4).

    nn.ConvTranspose2d(in_channels=LATENT_DIMENSION, out_channels=1024, kernel_size=4,  stride=2, padding=0),
    nn.ReLU(),
    nn.BatchNorm2d(1024),

    # Upsampling stack.

    nn.ConvTranspose2d(in_channels=1024, out_channels=512, kernel_size=4, stride=2, padding=1),
    nn.ReLU(),
    nn.BatchNorm2d(512),

    nn.ConvTranspose2d(in_channels=512, out_channels=256, kernel_size=4, stride=2, padding=1),
    nn.ReLU(),
    nn.BatchNorm2d(256),

    nn.ConvTranspose2d(in_channels=256, out_channels=128, kernel_size=4, stride=2, padding=1),
    nn.ReLU(),
    nn.BatchNorm2d(128),

    nn.ConvTranspose2d(in_channels=128, out_channels=3, kernel_size=4, stride=2, padding=1),
    nn.ReLU(),
    nn.BatchNorm2d(3),

    nn.Tanh(),
).cuda()


discriminator = nn.Sequential(

    # Downsampling stack.

    nn.Conv2d(in_channels=3, out_channels=128, kernel_size=4, stride=2, padding=1),
    nn.LeakyReLU(0.2),

    nn.Conv2d(in_channels=128, out_channels=256, kernel_size=4, stride=2, padding=1),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.2),

    nn.Conv2d(in_channels=256, out_channels=512, kernel_size=4, stride=2, padding=1),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.2),

    nn.Conv2d(in_channels=512, out_channels=1024, kernel_size=4, stride=2, padding=1),
    nn.BatchNorm2d(1024),
    nn.LeakyReLU(0.2),

    # Projection from (-1, 1024, 4, 4) to (-1, 1, 1, 1).

    nn.Conv2d(in_channels=1024, out_channels=1, kernel_size=4, stride=1, padding=0),
    nn.Flatten(),

    nn.Sigmoid(),
).cuda()

# %% [markdown]
# ### 2.3. Training

# %%
#@markdown

# !rm -rf samples checkpoints
# !mkdir samples checkpoints

# %%
#@markdown

#dataloader = DataLoader(dataset, shuffle=True, batch_size=BATCH_SIZE)


def get_fake_batch(batch_size: int) -> torch.Tensor:

    z = torch.randn(batch_size, LATENT_DIMENSION).view(-1, LATENT_DIMENSION, 1, 1).cuda()
    x = generator(z)

    return x


number_of_batches = len(augmented_dataset) // BATCH_SIZE
criterion = nn.BCELoss()
generator_optimizer = Adam(generator.parameters(), lr=1e-4)
discriminator_optimizer = Adam(discriminator.parameters(), lr=1e-4)

random.shuffle(augmented_dataset)

discriminator_losses = []
generator_losses = []

for epoch in range(EPOCHS):
    for batch_index in range(0, number_of_batches):
    # for batch_index, (real_batch, _) in enumerate(dataloader):

        # Train the discriminator.

        discriminator_optimizer.zero_grad()

        # if real_batch.size(0) != BATCH_SIZE:
        #     continue

        # real_batch = real_batch.cuda()

        real_batch_slice = slice(batch_index * BATCH_SIZE, (batch_index + 1) * BATCH_SIZE)
        real_batch = torch.cat(augmented_dataset[real_batch_slice]).view(BATCH_SIZE, 3, IMAGE_HEIGHT, IMAGE_WIDTH).cuda()
        real_labels = torch.ones((BATCH_SIZE, 1)).cuda()
        fake_batch = get_fake_batch(BATCH_SIZE).detach()
        fake_labels = torch.zeros((BATCH_SIZE, 1)).cuda()

        real_loss = criterion(discriminator(real_batch), real_labels)
        fake_loss = criterion(discriminator(fake_batch), fake_labels)
        discriminator_loss = real_loss + fake_loss
        discriminator_loss.backward()

        discriminator_optimizer.step()

        # Train the generator.

        generator_optimizer.zero_grad()

        fake_batch = get_fake_batch(BATCH_SIZE)
        real_labels = torch.ones((BATCH_SIZE, 1)).cuda()
        generator_loss = criterion(discriminator(fake_batch), real_labels)
        generator_loss.backward()

        generator_optimizer.step()

        # Record losses.

        discriminator_losses.append(discriminator_loss.item())
        generator_losses.append(generator_loss.item())

        if (batch_index + 1) % 5 == 0:
            mean_discriminator_loss = sum(discriminator_losses) / len(discriminator_losses)
            mean_generator_loss = sum(generator_losses) / len(generator_losses)
            discriminator_losses.clear()
            generator_losses.clear()

            print(f'[INFO] Epoch {epoch}/{EPOCHS}, Batch {batch_index}/{number_of_batches} - generator loss: {mean_generator_loss}, discriminator loss: {mean_discriminator_loss}')

    print('[INFO] Saving samples...')

    sample_images = renormalize(fake_batch[: 64].detach()).cpu().view(64, 3, IMAGE_HEIGHT, IMAGE_WIDTH)
    save_image(sample_images.data, os.path.join('samples', f'epoch-{epoch}-batch-{batch_index}.png'))

    print('[INFO] Saving checkpoints...')

    torch.save(discriminator, f'checkpoints/epoch-{epoch}-discriminator.pt')
    torch.save(generator, f'checkpoints/epoch-{epoch}-generator.pt')
# Out:
# [INFO] Epoch 0/300, Batch 4/784 - generator loss: 2.1348724603652953, discriminator loss: 0.8206498503684998
# [INFO] Epoch 0/300, Batch 9/784 - generator loss: 3.823407793045044, discriminator loss: 0.43898946046829224
# [INFO] Epoch 0/300, Batch 14/784 - generator loss: 6.043527984619141, discriminator loss: 0.09605499356985092
# [INFO] Epoch 0/300, Batch 19/784 - generator loss: 8.511597061157227, discriminator loss: 0.09670139849185944
# [INFO] Epoch 0/300, Batch 24/784 - generator loss: 11.256410217285156, discriminator loss: 0.10804294347763062
# [INFO] Epoch 0/300, Batch 29/784 - generator loss: 13.341007614135743, discriminator loss: 0.08272217959165573
# [INFO] Epoch 0/300, Batch 34/784 - generator loss: 13.845421028137206, discriminator loss: 0.026516332104802132
# [INFO] Epoch 0/300, Batch 39/784 - generator loss: 12.294143104553223, discriminator loss: 0.031355221197009085
# [INFO] Epoch 0/300, Batch 44/784 - generator loss: 12.533626365661622, discriminator loss: 0.01875983886420727
# [INFO] Epoch 0/300, Batch 49/784 - generator loss: 11.577917671203613, discriminator loss: 0.03720591049641371
# [INFO] Epoch 0/300, Batch 54/784 - generator loss: 12.950018119812011, discriminator loss: 0.018475055508315564
# [INFO] Epoch 0/300, Batch 59/784 - generator loss: 12.182445526123047, discriminator loss: 0.004168425081297755
# [INFO] Epoch 0/300, Batch 64/784 - generator loss: 9.632215118408203, discriminator loss: 0.007042486779391765
# [INFO] Epoch 0/300, Batch 69/784 - generator loss: 8.858691596984864, discriminator loss: 0.006086389068514109
# [INFO] Epoch 0/300, Batch 74/784 - generator loss: 9.677304077148438, discriminator loss: 0.001776040077675134
# [INFO] Epoch 0/300, Batch 79/784 - generator loss: 10.083770370483398, discriminator loss: 0.0009111234219744801
# [INFO] Epoch 0/300, Batch 84/784 - generator loss: 8.920334625244141, discriminator loss: 0.0013592129689641297
# [INFO] Epoch 0/300, Batch 89/784 - generator loss: 7.572994232177734, discriminator loss: 0.003908638376742601
# [INFO] Epoch 0/300, Batch 94/784 - generator loss: 8.510403728485107, discriminator loss: 0.004886197345331311
# [INFO] Epoch 0/300, Batch 99/784 - generator loss: 8.775867462158203, discriminator loss: 0.002962048724293709
# [INFO] Epoch 0/300, Batch 104/784 - generator loss: 8.888997268676757, discriminator loss: 0.0030841174302622676
# [INFO] Epoch 0/300, Batch 109/784 - generator loss: 8.730750465393067, discriminator loss: 0.0026683014817535876
# [INFO] Epoch 0/300, Batch 114/784 - generator loss: 8.153175163269044, discriminator loss: 0.005866353027522564
# [INFO] Epoch 0/300, Batch 119/784 - generator loss: 9.582283020019531, discriminator loss: 0.002610911871306598
# [INFO] Epoch 0/300, Batch 124/784 - generator loss: 8.554193115234375, discriminator loss: 0.004747720761224627
# [INFO] Epoch 0/300, Batch 129/784 - generator loss: 8.844072341918945, discriminator loss: 0.0034335005562752484
# [INFO] Epoch 0/300, Batch 134/784 - generator loss: 8.754056167602538, discriminator loss: 0.0025074703618884085
# [INFO] Epoch 0/300, Batch 139/784 - generator loss: 8.36041316986084, discriminator loss: 0.0025697984267026184
# [INFO] Epoch 0/300, Batch 144/784 - generator loss: 8.511088180541993, discriminator loss: 0.0032478028908371924
# [INFO] Epoch 0/300, Batch 149/784 - generator loss: 8.019153022766114, discriminator loss: 0.0035332970321178435
# [INFO] Epoch 0/300, Batch 154/784 - generator loss: 9.05648136138916, discriminator loss: 0.0019513163482770325
# [INFO] Epoch 0/300, Batch 159/784 - generator loss: 8.927669906616211, discriminator loss: 0.0037763209082186224
# [INFO] Epoch 0/300, Batch 164/784 - generator loss: 9.74715061187744, discriminator loss: 0.006026042345911265
# [INFO] Epoch 0/300, Batch 169/784 - generator loss: 9.40019931793213, discriminator loss: 0.0026789148338139056
# [INFO] Epoch 0/300, Batch 174/784 - generator loss: 8.893546676635742, discriminator loss: 0.004540798813104629
# [INFO] Epoch 0/300, Batch 179/784 - generator loss: 9.135309219360352, discriminator loss: 0.001961215562187135
# [INFO] Epoch 0/300, Batch 184/784 - generator loss: 9.151301956176757, discriminator loss: 0.002296810131520033
# [INFO] Epoch 0/300, Batch 189/784 - generator loss: 9.287350273132324, discriminator loss: 0.003943864884786308
# [INFO] Epoch 0/300, Batch 194/784 - generator loss: 9.802795028686523, discriminator loss: 0.002993292873725295
# [INFO] Epoch 0/300, Batch 199/784 - generator loss: 9.882733917236328, discriminator loss: 0.0031989030772820114
# [INFO] Epoch 0/300, Batch 204/784 - generator loss: 10.418360710144043, discriminator loss: 0.003316627210006118
# [INFO] Epoch 0/300, Batch 209/784 - generator loss: 9.239789772033692, discriminator loss: 0.002937091118656099
# [INFO] Epoch 0/300, Batch 214/784 - generator loss: 9.110049629211426, discriminator loss: 0.004104073625057936
# [INFO] Epoch 0/300, Batch 219/784 - generator loss: 10.442889595031739, discriminator loss: 0.002534819720312953
# [INFO] Epoch 0/300, Batch 224/784 - generator loss: 9.72243595123291, discriminator loss: 0.0053958801552653314
# [INFO] Epoch 0/300, Batch 229/784 - generator loss: 10.714286041259765, discriminator loss: 0.0021958539728075266
# [INFO] Epoch 0/300, Batch 234/784 - generator loss: 10.032686614990235, discriminator loss: 0.002853763196617365
# [INFO] Epoch 0/300, Batch 239/784 - generator loss: 10.444245529174804, discriminator loss: 0.00475129340775311
# [INFO] Epoch 0/300, Batch 244/784 - generator loss: 11.13276195526123, discriminator loss: 0.0019873887533321975
# [INFO] Epoch 0/300, Batch 249/784 - generator loss: 9.97779197692871, discriminator loss: 0.003247653925791383
# [INFO] Epoch 0/300, Batch 254/784 - generator loss: 10.785111427307129, discriminator loss: 0.0015724122058600187
# [INFO] Epoch 0/300, Batch 259/784 - generator loss: 9.762099266052246, discriminator loss: 0.0033354299375787377
# [INFO] Epoch 0/300, Batch 264/784 - generator loss: 11.239990043640137, discriminator loss: 0.0019554605707526205
# [INFO] Epoch 0/300, Batch 269/784 - generator loss: 9.79924259185791, discriminator loss: 0.0042783432640135285
# [INFO] Epoch 0/300, Batch 274/784 - generator loss: 11.580773735046387, discriminator loss: 0.0032319108402589338
# [INFO] Epoch 0/300, Batch 279/784 - generator loss: 12.56146183013916, discriminator loss: 0.001501981820911169
# [INFO] Epoch 0/300, Batch 284/784 - generator loss: 13.42952651977539, discriminator loss: 0.0030876471078954636
# [INFO] Epoch 0/300, Batch 289/784 - generator loss: 14.406294059753417, discriminator loss: 0.0028824725435697474
# [INFO] Epoch 0/300, Batch 294/784 - generator loss: 16.935421657562255, discriminator loss: 0.007083206958486699
# [INFO] Epoch 0/300, Batch 299/784 - generator loss: 20.2058464050293, discriminator loss: 0.009125747144571506
# [INFO] Epoch 0/300, Batch 304/784 - generator loss: 13.87523536682129, discriminator loss: 0.04524636736678076
# [INFO] Epoch 0/300, Batch 309/784 - generator loss: 12.330961799621582, discriminator loss: 0.019836863616365007
# [INFO] Epoch 0/300, Batch 314/784 - generator loss: 13.860871505737304, discriminator loss: 0.0032622096623526886
# [INFO] Epoch 0/300, Batch 319/784 - generator loss: 12.275310897827149, discriminator loss: 0.002630747889634222
# [INFO] Epoch 0/300, Batch 324/784 - generator loss: 12.052637100219727, discriminator loss: 0.0032871873583644627
# [INFO] Epoch 0/300, Batch 329/784 - generator loss: 9.935031318664551, discriminator loss: 0.005651317234151065
# [INFO] Epoch 0/300, Batch 334/784 - generator loss: 11.188289070129395, discriminator loss: 0.014490256505087017
# [INFO] Epoch 0/300, Batch 339/784 - generator loss: 10.99178638458252, discriminator loss: 0.001041240885388106
# [INFO] Epoch 0/300, Batch 344/784 - generator loss: 10.2366153717041, discriminator loss: 0.003378269961103797
# [INFO] Epoch 0/300, Batch 349/784 - generator loss: 11.716110610961914, discriminator loss: 0.0039013552479445933
# [INFO] Epoch 0/300, Batch 354/784 - generator loss: 11.435747528076172, discriminator loss: 0.026356980274431407
# [INFO] Epoch 0/300, Batch 359/784 - generator loss: 12.520088958740235, discriminator loss: 0.006059702462516725
# [INFO] Epoch 0/300, Batch 364/784 - generator loss: 11.338610076904297, discriminator loss: 0.0034426937578245997
# [INFO] Epoch 0/300, Batch 369/784 - generator loss: 13.569451141357423, discriminator loss: 0.004224902550049592
# [INFO] Epoch 0/300, Batch 374/784 - generator loss: 9.62847967147827, discriminator loss: 0.004138089786283672
# [INFO] Epoch 0/300, Batch 379/784 - generator loss: 11.201555442810058, discriminator loss: 0.0029656541883014143
# [INFO] Epoch 0/300, Batch 384/784 - generator loss: 10.1923189163208, discriminator loss: 0.005725586693733931
# [INFO] Epoch 0/300, Batch 389/784 - generator loss: 10.482122421264648, discriminator loss: 0.004195341793820262
# [INFO] Epoch 0/300, Batch 394/784 - generator loss: 10.90909194946289, discriminator loss: 0.002813188103027642
# [INFO] Epoch 0/300, Batch 399/784 - generator loss: 10.637683868408203, discriminator loss: 0.0037563723046332596
# [INFO] Epoch 0/300, Batch 404/784 - generator loss: 11.170350074768066, discriminator loss: 0.0033601994393393396
# [INFO] Epoch 0/300, Batch 409/784 - generator loss: 11.534420776367188, discriminator loss: 0.003752971859648824
# [INFO] Epoch 0/300, Batch 414/784 - generator loss: 20.871850204467773, discriminator loss: 0.022745556014706382
# [INFO] Epoch 0/300, Batch 419/784 - generator loss: 28.683203506469727, discriminator loss: 8.735235969652422e-05
# [INFO] Epoch 0/300, Batch 424/784 - generator loss: 27.64873504638672, discriminator loss: 0.002124404942151159
# [INFO] Epoch 0/300, Batch 429/784 - generator loss: 25.887916564941406, discriminator loss: 0.0015674563386710362
# [INFO] Epoch 0/300, Batch 434/784 - generator loss: 22.244849395751952, discriminator loss: 0.00024416856176685543
# [INFO] Epoch 0/300, Batch 439/784 - generator loss: 18.235236740112306, discriminator loss: 0.0030554365017451345
# [INFO] Epoch 0/300, Batch 444/784 - generator loss: 15.258365440368653, discriminator loss: 0.0018329297308810055
# [INFO] Epoch 0/300, Batch 449/784 - generator loss: 15.048558235168457, discriminator loss: 0.016186060151085258
# [INFO] Epoch 0/300, Batch 454/784 - generator loss: 17.05052490234375, discriminator loss: 0.0041286730600404555
# [INFO] Epoch 0/300, Batch 459/784 - generator loss: 14.209762001037598, discriminator loss: 0.014730827719904482
# [INFO] Epoch 0/300, Batch 464/784 - generator loss: 15.15232162475586, discriminator loss: 0.004723422136157751
# [INFO] Epoch 0/300, Batch 469/784 - generator loss: 11.869965171813964, discriminator loss: 0.018874523183330893
# [INFO] Epoch 0/300, Batch 474/784 - generator loss: 19.263705444335937, discriminator loss: 0.006532441681338241
# [INFO] Epoch 0/300, Batch 479/784 - generator loss: 18.26778907775879, discriminator loss: 0.014232115936465561
# [INFO] Epoch 0/300, Batch 484/784 - generator loss: 18.46532917022705, discriminator loss: 0.008690596750238911
# [INFO] Epoch 0/300, Batch 489/784 - generator loss: 23.778977966308595, discriminator loss: 0.0030681549935252404
# [INFO] Epoch 0/300, Batch 494/784 - generator loss: 19.56177673339844, discriminator loss: 0.0033377926083630882
# [INFO] Epoch 0/300, Batch 499/784 - generator loss: 19.785411834716797, discriminator loss: 0.005563420813996345
# [INFO] Epoch 0/300, Batch 504/784 - generator loss: 18.837336921691893, discriminator loss: 0.006484318269576761
# [INFO] Epoch 0/300, Batch 509/784 - generator loss: 21.65212936401367, discriminator loss: 0.006268115151033271
# [INFO] Epoch 0/300, Batch 514/784 - generator loss: 15.706511116027832, discriminator loss: 0.007017879095656099
# [INFO] Epoch 0/300, Batch 519/784 - generator loss: 20.471096420288085, discriminator loss: 0.008981086252606473
# [INFO] Epoch 0/300, Batch 524/784 - generator loss: 16.471467971801758, discriminator loss: 0.004187612966052257
# [INFO] Epoch 0/300, Batch 529/784 - generator loss: 13.452080154418946, discriminator loss: 0.0005991319616441615
# [INFO] Epoch 0/300, Batch 534/784 - generator loss: 11.80568561553955, discriminator loss: 0.005960690311621874
# [INFO] Epoch 0/300, Batch 539/784 - generator loss: 13.392888259887695, discriminator loss: 0.007296328793745488
# [INFO] Epoch 0/300, Batch 544/784 - generator loss: 14.601543426513672, discriminator loss: 0.004288661945611239
# [INFO] Epoch 0/300, Batch 549/784 - generator loss: 12.269456100463866, discriminator loss: 0.015182303031906486
# [INFO] Epoch 0/300, Batch 554/784 - generator loss: 12.22717227935791, discriminator loss: 0.001619571610353887
# [INFO] Epoch 0/300, Batch 559/784 - generator loss: 14.75942440032959, discriminator loss: 0.0015964549384079874
# [INFO] Epoch 0/300, Batch 564/784 - generator loss: 11.614821815490723, discriminator loss: 0.017466973466798662
# [INFO] Epoch 0/300, Batch 569/784 - generator loss: 12.538218879699707, discriminator loss: 0.03073141056811437
# [INFO] Epoch 0/300, Batch 574/784 - generator loss: 19.556113052368165, discriminator loss: 0.1367082616110565
# [INFO] Epoch 0/300, Batch 579/784 - generator loss: 16.308480072021485, discriminator loss: 0.08059904524125158
# [INFO] Epoch 0/300, Batch 584/784 - generator loss: 12.604508018493652, discriminator loss: 0.013790112710557878
# [INFO] Epoch 0/300, Batch 589/784 - generator loss: 13.339872741699219, discriminator loss: 0.002019376144744456
# [INFO] Epoch 0/300, Batch 594/784 - generator loss: 11.8396390914917, discriminator loss: 0.0025027268915437163
# [INFO] Epoch 0/300, Batch 599/784 - generator loss: 9.71347713470459, discriminator loss: 0.009136690944433212
# [INFO] Epoch 0/300, Batch 604/784 - generator loss: 10.017197036743164, discriminator loss: 0.025027510710060596
# [INFO] Epoch 0/300, Batch 609/784 - generator loss: 9.583047103881835, discriminator loss: 0.012447570450603962
# [INFO] Epoch 0/300, Batch 614/784 - generator loss: 10.800094413757325, discriminator loss: 0.0026072475826367735
# [INFO] Epoch 0/300, Batch 619/784 - generator loss: 10.886228942871094, discriminator loss: 0.005850212043151259
# [INFO] Epoch 0/300, Batch 624/784 - generator loss: 11.5380859375, discriminator loss: 0.014561215229332448
# [INFO] Epoch 0/300, Batch 629/784 - generator loss: 10.150186920166016, discriminator loss: 0.004879629891365767
# [INFO] Epoch 0/300, Batch 634/784 - generator loss: 10.149705123901366, discriminator loss: 0.010336878895759582
# [INFO] Epoch 0/300, Batch 639/784 - generator loss: 9.718571662902832, discriminator loss: 0.0167277276981622
# [INFO] Epoch 0/300, Batch 644/784 - generator loss: 10.585823059082031, discriminator loss: 0.004086354933679104
# [INFO] Epoch 0/300, Batch 649/784 - generator loss: 9.472336578369141, discriminator loss: 0.0104491981677711
# [INFO] Epoch 0/300, Batch 654/784 - generator loss: 12.912510108947753, discriminator loss: 0.03463458146434277
# [INFO] Epoch 0/300, Batch 659/784 - generator loss: 16.24716453552246, discriminator loss: 0.005819342122413218
# [INFO] Epoch 0/300, Batch 664/784 - generator loss: 12.621986389160156, discriminator loss: 0.00787301231175661
# [INFO] Epoch 0/300, Batch 669/784 - generator loss: 12.70527286529541, discriminator loss: 0.027629117021569984
# [INFO] Epoch 0/300, Batch 674/784 - generator loss: 13.907940483093261, discriminator loss: 0.050985622126609086
# [INFO] Epoch 0/300, Batch 679/784 - generator loss: 13.418196868896484, discriminator loss: 0.0007610164582729339
# [INFO] Epoch 0/300, Batch 684/784 - generator loss: 10.261437606811523, discriminator loss: 0.0062594530696515
# [INFO] Epoch 0/300, Batch 689/784 - generator loss: 10.107983779907226, discriminator loss: 0.016255331877619027
# [INFO] Epoch 0/300, Batch 694/784 - generator loss: 10.548309326171875, discriminator loss: 0.010375440772622823
# [INFO] Epoch 0/300, Batch 699/784 - generator loss: 10.222162818908691, discriminator loss: 0.01018211767077446
# [INFO] Epoch 0/300, Batch 704/784 - generator loss: 13.123136138916015, discriminator loss: 0.320213969424367
# [INFO] Epoch 0/300, Batch 709/784 - generator loss: 16.962242126464844, discriminator loss: 0.06676391436485574
# [INFO] Epoch 0/300, Batch 714/784 - generator loss: 11.044215393066406, discriminator loss: 0.03873788826167583
# [INFO] Epoch 0/300, Batch 719/784 - generator loss: 14.487210464477538, discriminator loss: 0.002830596291460097
# [INFO] Epoch 0/300, Batch 724/784 - generator loss: 11.624746894836425, discriminator loss: 0.01326666222885251
# [INFO] Epoch 0/300, Batch 729/784 - generator loss: 9.13927001953125, discriminator loss: 0.01509586488828063
# [INFO] Epoch 0/300, Batch 734/784 - generator loss: 8.67902364730835, discriminator loss: 0.02911477240268141
# [INFO] Epoch 0/300, Batch 739/784 - generator loss: 10.585107231140137, discriminator loss: 0.035246496088802814
# [INFO] Epoch 0/300, Batch 744/784 - generator loss: 8.164023303985596, discriminator loss: 0.05966134052723646
# [INFO] Epoch 0/300, Batch 749/784 - generator loss: 10.819192695617676, discriminator loss: 0.02704743854701519
# [INFO] Epoch 0/300, Batch 754/784 - generator loss: 8.229696273803711, discriminator loss: 0.060076812840998174
# [INFO] Epoch 0/300, Batch 759/784 - generator loss: 9.840288734436035, discriminator loss: 0.022625318728387356
# [INFO] Epoch 0/300, Batch 764/784 - generator loss: 11.028841781616212, discriminator loss: 0.031289582559838894
# [INFO] Epoch 0/300, Batch 769/784 - generator loss: 9.628332710266113, discriminator loss: 0.0100495345890522
# [INFO] Epoch 0/300, Batch 774/784 - generator loss: 9.374563026428223, discriminator loss: 0.026797016430646182
# [INFO] Epoch 0/300, Batch 779/784 - generator loss: 11.372601127624511, discriminator loss: 0.004125530272722245
# [INFO] Saving samples...
# [INFO] Saving checkpoints...
# [INFO] Epoch 1/300, Batch 4/784 - generator loss: 10.145759370591906, discriminator loss: 0.01758040099715193
# [INFO] Epoch 1/300, Batch 9/784 - generator loss: 10.031338310241699, discriminator loss: 0.06110088750720024
# [INFO] Epoch 1/300, Batch 14/784 - generator loss: 18.826429748535155, discriminator loss: 0.012821405055001378
# [INFO] Epoch 1/300, Batch 19/784 - generator loss: 15.869941329956054, discriminator loss: 0.00620642764843069
# [INFO] Epoch 1/300, Batch 24/784 - generator loss: 9.809373664855958, discriminator loss: 0.015036957059055566
# [INFO] Epoch 1/300, Batch 29/784 - generator loss: 11.962677574157714, discriminator loss: 0.01518524270504713
# [INFO] Epoch 1/300, Batch 34/784 - generator loss: 10.6426851272583, discriminator loss: 0.030456370674073696
# [INFO] Epoch 1/300, Batch 39/784 - generator loss: 10.97572727203369, discriminator loss: 0.00976882695686072
# [INFO] Epoch 1/300, Batch 44/784 - generator loss: 10.283403205871583, discriminator loss: 0.007331255311146379
# [INFO] Epoch 1/300, Batch 49/784 - generator loss: 8.695814895629884, discriminator loss: 0.015564218163490295
# [INFO] Epoch 1/300, Batch 54/784 - generator loss: 10.3073148727417, discriminator loss: 0.009819145686924458
# [INFO] Epoch 1/300, Batch 59/784 - generator loss: 9.421344661712647, discriminator loss: 0.0463101577013731
# [INFO] Epoch 1/300, Batch 64/784 - generator loss: 16.34039330482483, discriminator loss: 1.7977061420679092
# [INFO] Epoch 1/300, Batch 69/784 - generator loss: 7.088230895996094, discriminator loss: 0.1422245979309082
# [INFO] Epoch 1/300, Batch 74/784 - generator loss: 7.237422180175781, discriminator loss: 0.17477504685521125
# [INFO] Epoch 1/300, Batch 79/784 - generator loss: 6.711451625823974, discriminator loss: 0.05344240851700306
# [INFO] Epoch 1/300, Batch 84/784 - generator loss: 6.433708000183105, discriminator loss: 0.0701212577521801
# [INFO] Epoch 1/300, Batch 89/784 - generator loss: 5.982710361480713, discriminator loss: 0.061042788252234456
# [INFO] Epoch 1/300, Batch 94/784 - generator loss: 5.9417116165161135, discriminator loss: 0.05365297645330429
# [INFO] Epoch 1/300, Batch 99/784 - generator loss: 5.587499141693115, discriminator loss: 0.07289045006036758
# [INFO] Epoch 1/300, Batch 104/784 - generator loss: 6.118167114257813, discriminator loss: 0.06660358868539333
# [INFO] Epoch 1/300, Batch 109/784 - generator loss: 5.543486881256103, discriminator loss: 0.031010330840945243
# [INFO] Epoch 1/300, Batch 114/784 - generator loss: 5.987753295898438, discriminator loss: 0.024514821544289588
# [INFO] Epoch 1/300, Batch 119/784 - generator loss: 5.915957260131836, discriminator loss: 0.041623158380389214
# [INFO] Epoch 1/300, Batch 124/784 - generator loss: 5.768924140930176, discriminator loss: 0.0719939962029457
# [INFO] Epoch 1/300, Batch 129/784 - generator loss: 6.3570598602294925, discriminator loss: 0.05159932002425194
# [INFO] Epoch 1/300, Batch 134/784 - generator loss: 6.099283981323242, discriminator loss: 0.034321239590644835
# [INFO] Epoch 1/300, Batch 139/784 - generator loss: 7.087390041351318, discriminator loss: 0.04616398364305496
# [INFO] Epoch 1/300, Batch 144/784 - generator loss: 7.582924270629883, discriminator loss: 0.03234650753438473
# [INFO] Epoch 1/300, Batch 149/784 - generator loss: 7.112027645111084, discriminator loss: 0.03910305127501488
# [INFO] Epoch 1/300, Batch 154/784 - generator loss: 6.32042875289917, discriminator loss: 0.056597090885043146
# [INFO] Epoch 1/300, Batch 159/784 - generator loss: 6.513337802886963, discriminator loss: 0.039384965971112254
# [INFO] Epoch 1/300, Batch 164/784 - generator loss: 6.832983112335205, discriminator loss: 0.02164632435888052
# [INFO] Epoch 1/300, Batch 169/784 - generator loss: 6.535555076599121, discriminator loss: 0.03582417592406273
# [INFO] Epoch 1/300, Batch 174/784 - generator loss: 7.127534103393555, discriminator loss: 0.05024445503950119
# [INFO] Epoch 1/300, Batch 179/784 - generator loss: 7.272940635681152, discriminator loss: 0.040574376657605174
# [INFO] Epoch 1/300, Batch 184/784 - generator loss: 8.131402015686035, discriminator loss: 0.029877603985369205
# [INFO] Epoch 1/300, Batch 189/784 - generator loss: 10.532866859436036, discriminator loss: 0.07677888795733452
# [INFO] Epoch 1/300, Batch 194/784 - generator loss: 11.149689292907714, discriminator loss: 0.03634580997750163
# [INFO] Epoch 1/300, Batch 199/784 - generator loss: 12.442538833618164, discriminator loss: 0.012178090680390597
# [INFO] Epoch 1/300, Batch 204/784 - generator loss: 9.430467414855958, discriminator loss: 0.05408414527773857
# [INFO] Epoch 1/300, Batch 209/784 - generator loss: 10.052438735961914, discriminator loss: 0.027929322421550752
# [INFO] Epoch 1/300, Batch 214/784 - generator loss: 10.613601303100586, discriminator loss: 0.03483331240713596
# [INFO] Epoch 1/300, Batch 219/784 - generator loss: 9.923258972167968, discriminator loss: 0.038965095207095145
# [INFO] Epoch 1/300, Batch 224/784 - generator loss: 9.696520042419433, discriminator loss: 0.031266584619879724
# [INFO] Epoch 1/300, Batch 229/784 - generator loss: 8.848981285095215, discriminator loss: 0.03771849535405636
# [INFO] Epoch 1/300, Batch 234/784 - generator loss: 8.9107497215271, discriminator loss: 0.08960163593292236
# [INFO] Epoch 1/300, Batch 239/784 - generator loss: 9.174051856994629, discriminator loss: 0.04833366535604
# [INFO] Epoch 1/300, Batch 244/784 - generator loss: 9.9705228805542, discriminator loss: 0.03966935276985169
# [INFO] Epoch 1/300, Batch 249/784 - generator loss: 8.398415184020996, discriminator loss: 0.051944149658083916
# [INFO] Epoch 1/300, Batch 254/784 - generator loss: 8.409036445617676, discriminator loss: 0.03220133194699883
# [INFO] Epoch 1/300, Batch 259/784 - generator loss: 9.24977149963379, discriminator loss: 0.02086029518395662
# [INFO] Epoch 1/300, Batch 264/784 - generator loss: 7.468131351470947, discriminator loss: 0.04223694074898958
# [INFO] Epoch 1/300, Batch 269/784 - generator loss: 7.629979038238526, discriminator loss: 0.04441543444991112
# [INFO] Epoch 1/300, Batch 274/784 - generator loss: 6.822202968597412, discriminator loss: 0.03471426256000996
# [INFO] Epoch 1/300, Batch 279/784 - generator loss: 7.527088165283203, discriminator loss: 0.03512544874101877
# [INFO] Epoch 1/300, Batch 284/784 - generator loss: 7.358089447021484, discriminator loss: 0.04475062815472484
# [INFO] Epoch 1/300, Batch 289/784 - generator loss: 7.911483573913574, discriminator loss: 0.010971234692260624
# [INFO] Epoch 1/300, Batch 294/784 - generator loss: 8.192380905151367, discriminator loss: 0.0068223211914300915
# [INFO] Epoch 1/300, Batch 299/784 - generator loss: 7.882855224609375, discriminator loss: 0.017044411227107047
# [INFO] Epoch 1/300, Batch 304/784 - generator loss: 7.2676983833312985, discriminator loss: 0.023276007361710073
# [INFO] Epoch 1/300, Batch 309/784 - generator loss: 6.698917579650879, discriminator loss: 0.050965193938463924
# [INFO] Epoch 1/300, Batch 314/784 - generator loss: 9.233417129516601, discriminator loss: 0.0059755748137831684
# [INFO] Epoch 1/300, Batch 319/784 - generator loss: 8.540284824371337, discriminator loss: 0.0034718400333076716
# [INFO] Epoch 1/300, Batch 324/784 - generator loss: 7.3592206001281735, discriminator loss: 0.023678339272737502
# [INFO] Epoch 1/300, Batch 329/784 - generator loss: 7.20180377960205, discriminator loss: 0.015149459801614284
# [INFO] Epoch 1/300, Batch 334/784 - generator loss: 8.970879459381104, discriminator loss: 0.01724591888487339
# [INFO] Epoch 1/300, Batch 339/784 - generator loss: 8.801605224609375, discriminator loss: 0.005242886394262314
# [INFO] Epoch 1/300, Batch 344/784 - generator loss: 6.950560760498047, discriminator loss: 0.016204061452299356
# [INFO] Epoch 1/300, Batch 349/784 - generator loss: 9.11108341217041, discriminator loss: 0.0222835011780262
# [INFO] Epoch 1/300, Batch 354/784 - generator loss: 8.173087692260742, discriminator loss: 0.022530771791934967
# [INFO] Epoch 1/300, Batch 359/784 - generator loss: 8.365890502929688, discriminator loss: 0.07573563791811466
# [INFO] Epoch 1/300, Batch 364/784 - generator loss: 12.505736541748046, discriminator loss: 0.09619452459737658
# [INFO] Epoch 1/300, Batch 369/784 - generator loss: 10.284840774536132, discriminator loss: 0.03365987529978156
# [INFO] Epoch 1/300, Batch 374/784 - generator loss: 8.271295166015625, discriminator loss: 0.05932190530002117
# [INFO] Epoch 1/300, Batch 379/784 - generator loss: 7.75742826461792, discriminator loss: 0.05616100151091814
# [INFO] Epoch 1/300, Batch 384/784 - generator loss: 7.978176689147949, discriminator loss: 0.028859975375235082
# [INFO] Epoch 1/300, Batch 389/784 - generator loss: 7.649129486083984, discriminator loss: 0.027840079087764025
# [INFO] Epoch 1/300, Batch 394/784 - generator loss: 7.859905242919922, discriminator loss: 0.03137061714660376
# [INFO] Epoch 1/300, Batch 399/784 - generator loss: 6.977059936523437, discriminator loss: 0.03200817219913006
# [INFO] Epoch 1/300, Batch 404/784 - generator loss: 7.96223726272583, discriminator loss: 0.01647979812696576
# [INFO] Epoch 1/300, Batch 409/784 - generator loss: 10.094742584228516, discriminator loss: 0.0033731159754097463
# [INFO] Epoch 1/300, Batch 414/784 - generator loss: 9.24557180404663, discriminator loss: 0.05601218871306628
# [INFO] Epoch 1/300, Batch 419/784 - generator loss: 11.450155639648438, discriminator loss: 0.03659851290285587
# [INFO] Epoch 1/300, Batch 424/784 - generator loss: 9.652129554748536, discriminator loss: 0.022683638008311392
# [INFO] Epoch 1/300, Batch 429/784 - generator loss: 8.598172569274903, discriminator loss: 0.07021968066692352
# [INFO] Epoch 1/300, Batch 434/784 - generator loss: 13.938774013519287, discriminator loss: 0.2129650033544749
# [INFO] Epoch 1/300, Batch 439/784 - generator loss: 20.758191680908205, discriminator loss: 0.15787580813048407
# [INFO] Epoch 1/300, Batch 444/784 - generator loss: 13.945929145812988, discriminator loss: 0.08149159385357052
# [INFO] Epoch 1/300, Batch 449/784 - generator loss: 12.477615356445312, discriminator loss: 0.04526210362091661
# [INFO] Epoch 1/300, Batch 454/784 - generator loss: 9.1768798828125, discriminator loss: 0.09345033019781113
# [INFO] Epoch 1/300, Batch 459/784 - generator loss: 9.226154708862305, discriminator loss: 0.1448420912027359
# [INFO] Epoch 1/300, Batch 464/784 - generator loss: 9.622727012634277, discriminator loss: 0.07685400024056435
# [INFO] Epoch 1/300, Batch 469/784 - generator loss: 8.592956161499023, discriminator loss: 0.1801651181653142
# [INFO] Epoch 1/300, Batch 474/784 - generator loss: 9.878231143951416, discriminator loss: 0.28399801440536976
# [INFO] Epoch 1/300, Batch 479/784 - generator loss: 12.443868255615234, discriminator loss: 0.09360879054293036
# [INFO] Epoch 1/300, Batch 484/784 - generator loss: 8.96034641265869, discriminator loss: 0.021348441392183302
# [INFO] Epoch 1/300, Batch 489/784 - generator loss: 7.867961883544922, discriminator loss: 0.025367116928100585
# [INFO] Epoch 1/300, Batch 494/784 - generator loss: 9.331970596313477, discriminator loss: 0.05753666665405035
# [INFO] Epoch 1/300, Batch 499/784 - generator loss: 8.218978309631348, discriminator loss: 0.039596549794077875
# [INFO] Epoch 1/300, Batch 504/784 - generator loss: 9.454980278015137, discriminator loss: 0.015100066596642137
# [INFO] Epoch 1/300, Batch 509/784 - generator loss: 9.158085823059082, discriminator loss: 0.0591840960085392
# [INFO] Epoch 1/300, Batch 514/784 - generator loss: 8.200410270690918, discriminator loss: 0.04020251929759979
# [INFO] Epoch 1/300, Batch 519/784 - generator loss: 10.04909381866455, discriminator loss: 0.026202427595853804
# [INFO] Epoch 1/300, Batch 524/784 - generator loss: 8.333715629577636, discriminator loss: 0.10713957222178579
# [INFO] Epoch 1/300, Batch 529/784 - generator loss: 12.249907875061036, discriminator loss: 0.014501933194696903
# [INFO] Epoch 1/300, Batch 534/784 - generator loss: 9.153553581237793, discriminator loss: 0.09998676106333733
# [INFO] Epoch 1/300, Batch 539/784 - generator loss: 10.16548194885254, discriminator loss: 0.13095367439091204
# [INFO] Epoch 1/300, Batch 544/784 - generator loss: 10.062492179870606, discriminator loss: 0.03516857884824276
# [INFO] Epoch 1/300, Batch 549/784 - generator loss: 7.462883758544922, discriminator loss: 0.1520483076572418
# [INFO] Epoch 1/300, Batch 554/784 - generator loss: 9.430889415740968, discriminator loss: 0.07067231610417365
# [INFO] Epoch 1/300, Batch 559/784 - generator loss: 8.282606506347657, discriminator loss: 0.12561015812680126
# [INFO] Epoch 1/300, Batch 564/784 - generator loss: 13.888991928100586, discriminator loss: 0.07997580002993346
# [INFO] Epoch 1/300, Batch 569/784 - generator loss: 10.235518264770509, discriminator loss: 0.05021182131022215
# [INFO] Epoch 1/300, Batch 574/784 - generator loss: 8.698396682739258, discriminator loss: 0.14153270721435546
# [INFO] Epoch 1/300, Batch 579/784 - generator loss: 7.4608909606933596, discriminator loss: 0.28085211515426634
# [INFO] Epoch 1/300, Batch 584/784 - generator loss: 10.894726753234863, discriminator loss: 0.06794483996927739
# [INFO] Epoch 1/300, Batch 589/784 - generator loss: 7.387312602996826, discriminator loss: 0.09391149356961251
# [INFO] Epoch 1/300, Batch 594/784 - generator loss: 9.150238990783691, discriminator loss: 0.04614419918507338
# [INFO] Epoch 1/300, Batch 599/784 - generator loss: 6.152265644073486, discriminator loss: 0.04840676188468933
# [INFO] Epoch 1/300, Batch 604/784 - generator loss: 6.609806966781616, discriminator loss: 0.8426914974115789
# [INFO] Epoch 1/300, Batch 609/784 - generator loss: 7.6337456703186035, discriminator loss: 0.2970155502669513
# [INFO] Epoch 1/300, Batch 614/784 - generator loss: 7.411953926086426, discriminator loss: 0.06096805511042476
# [INFO] Epoch 1/300, Batch 619/784 - generator loss: 8.75538387298584, discriminator loss: 0.04481076002120972
# [INFO] Epoch 1/300, Batch 624/784 - generator loss: 6.074219036102295, discriminator loss: 0.0229764923453331
# [INFO] Epoch 1/300, Batch 629/784 - generator loss: 6.900767803192139, discriminator loss: 0.05809961184859276
# [INFO] Epoch 1/300, Batch 634/784 - generator loss: 5.817539978027344, discriminator loss: 0.04238583780825138
# [INFO] Epoch 1/300, Batch 639/784 - generator loss: 5.5818939208984375, discriminator loss: 0.06420191843062639
# [INFO] Epoch 1/300, Batch 644/784 - generator loss: 6.816136455535888, discriminator loss: 0.061144965887069705
# [INFO] Epoch 1/300, Batch 649/784 - generator loss: 6.349120807647705, discriminator loss: 0.04955088756978512
# [INFO] Epoch 1/300, Batch 654/784 - generator loss: 6.955931282043457, discriminator loss: 0.026477046310901642
# [INFO] Epoch 1/300, Batch 659/784 - generator loss: 5.478654861450195, discriminator loss: 0.03342130221426487
# [INFO] Epoch 1/300, Batch 664/784 - generator loss: 6.376079368591308, discriminator loss: 0.04338592514395714
# [INFO] Epoch 1/300, Batch 669/784 - generator loss: 6.138620471954345, discriminator loss: 0.03190587805584073
# [INFO] Epoch 1/300, Batch 674/784 - generator loss: 8.656700897216798, discriminator loss: 0.033218732988461855
# [INFO] Epoch 1/300, Batch 679/784 - generator loss: 5.088098430633545, discriminator loss: 0.028392958268523217
# [INFO] Epoch 1/300, Batch 684/784 - generator loss: 7.784329414367676, discriminator loss: 0.024787696450948714
# [INFO] Epoch 1/300, Batch 689/784 - generator loss: 6.131874942779541, discriminator loss: 0.04793646819889545
# [INFO] Epoch 1/300, Batch 694/784 - generator loss: 6.032656669616699, discriminator loss: 0.05308931916952133
# [INFO] Epoch 1/300, Batch 699/784 - generator loss: 9.269502067565918, discriminator loss: 0.07979660481214523
# [INFO] Epoch 1/300, Batch 704/784 - generator loss: 6.657182216644287, discriminator loss: 0.03041467610746622
# [INFO] Epoch 1/300, Batch 709/784 - generator loss: 7.387223529815674, discriminator loss: 0.10497408658266068
# [INFO] Epoch 1/300, Batch 714/784 - generator loss: 9.742320728302001, discriminator loss: 0.21208109688013793
# [INFO] Epoch 1/300, Batch 719/784 - generator loss: 12.249327087402344, discriminator loss: 0.3113711983896792
# [INFO] Epoch 1/300, Batch 724/784 - generator loss: 12.997077369689942, discriminator loss: 0.11948542976751923
# [INFO] Epoch 1/300, Batch 729/784 - generator loss: 8.761517524719238, discriminator loss: 0.06810733303427696
# [INFO] Epoch 1/300, Batch 734/784 - generator loss: 7.963330459594727, discriminator loss: 0.0998470813035965
# [INFO] Epoch 1/300, Batch 739/784 - generator loss: 7.152560043334961, discriminator loss: 0.0727760598063469
# [INFO] Epoch 1/300, Batch 744/784 - generator loss: 5.7158280372619625, discriminator loss: 0.1517096970230341
# [INFO] Epoch 1/300, Batch 749/784 - generator loss: 8.4281795501709, discriminator loss: 0.13356285877525806
# [INFO] Epoch 1/300, Batch 754/784 - generator loss: 7.657608985900879, discriminator loss: 0.13332434091717005
# [INFO] Epoch 1/300, Batch 759/784 - generator loss: 10.157562637329102, discriminator loss: 0.04004103578627109
# [INFO] Epoch 1/300, Batch 764/784 - generator loss: 8.46709384918213, discriminator loss: 0.033212913759052755
# [INFO] Epoch 1/300, Batch 769/784 - generator loss: 8.913785934448242, discriminator loss: 0.05266847275197506
# [INFO] Epoch 1/300, Batch 774/784 - generator loss: 6.168812084197998, discriminator loss: 0.10642019435763359
# [INFO] Epoch 1/300, Batch 779/784 - generator loss: 9.516938781738281, discriminator loss: 0.046116963401436804
# [INFO] Saving samples...
# [INFO] Saving checkpoints...
# [INFO] Epoch 2/300, Batch 4/784 - generator loss: 8.150368001725939, discriminator loss: 0.08919818544139464
# [INFO] Epoch 2/300, Batch 9/784 - generator loss: 9.515110778808594, discriminator loss: 0.05262224543839693
# [INFO] Epoch 2/300, Batch 14/784 - generator loss: 9.255511951446532, discriminator loss: 0.017608561739325523
# [INFO] Epoch 2/300, Batch 19/784 - generator loss: 9.505221748352051, discriminator loss: 0.03513221181929112
# [INFO] Epoch 2/300, Batch 24/784 - generator loss: 8.838294410705567, discriminator loss: 0.020443096896633504
# [INFO] Epoch 2/300, Batch 29/784 - generator loss: 11.103421401977538, discriminator loss: 0.016107929730787875
# [INFO] Epoch 2/300, Batch 34/784 - generator loss: 8.019721126556396, discriminator loss: 0.045278513617813584
# [INFO] Epoch 2/300, Batch 39/784 - generator loss: 9.332905960083007, discriminator loss: 0.12037920989096165
# [INFO] Epoch 2/300, Batch 44/784 - generator loss: 11.52451820373535, discriminator loss: 0.03224368989467621
# [INFO] Epoch 2/300, Batch 49/784 - generator loss: 11.744882011413575, discriminator loss: 0.013306823140010238
# [INFO] Epoch 2/300, Batch 54/784 - generator loss: 9.595235443115234, discriminator loss: 0.04561270736157894
# [INFO] Epoch 2/300, Batch 59/784 - generator loss: 8.296969604492187, discriminator loss: 0.16658714208751918
# [INFO] Epoch 2/300, Batch 64/784 - generator loss: 13.48033857345581, discriminator loss: 1.0241647005081176
# [INFO] Epoch 2/300, Batch 69/784 - generator loss: 7.958844184875488, discriminator loss: 0.19718280099332333
# [INFO] Epoch 2/300, Batch 74/784 - generator loss: 11.24646167755127, discriminator loss: 0.21592607386410237
# [INFO] Epoch 2/300, Batch 79/784 - generator loss: 7.761311149597168, discriminator loss: 0.02892311569303274
# [INFO] Epoch 2/300, Batch 84/784 - generator loss: 7.790758514404297, discriminator loss: 0.08921820744872093
# [INFO] Epoch 2/300, Batch 89/784 - generator loss: 9.348687553405762, discriminator loss: 0.01778411464765668
# [INFO] Epoch 2/300, Batch 94/784 - generator loss: 5.909815406799316, discriminator loss: 0.06272606700658798
# [INFO] Epoch 2/300, Batch 99/784 - generator loss: 6.309568309783936, discriminator loss: 0.1826301969587803
# [INFO] Epoch 2/300, Batch 104/784 - generator loss: 4.734398126602173, discriminator loss: 0.21253447681665422
# [INFO] Epoch 2/300, Batch 109/784 - generator loss: 8.543071365356445, discriminator loss: 0.06298598311841488
# [INFO] Epoch 2/300, Batch 114/784 - generator loss: 5.399375915527344, discriminator loss: 0.048958370555192234
# [INFO] Epoch 2/300, Batch 119/784 - generator loss: 7.109004878997803, discriminator loss: 0.04540444696322084
# [INFO] Epoch 2/300, Batch 124/784 - generator loss: 8.358876991271973, discriminator loss: 0.04087467957288027
# [INFO] Epoch 2/300, Batch 129/784 - generator loss: 5.573245620727539, discriminator loss: 0.08629922457039356
# [INFO] Epoch 2/300, Batch 134/784 - generator loss: 6.247951221466065, discriminator loss: 0.15348482131958008
# [INFO] Epoch 2/300, Batch 139/784 - generator loss: 5.259516334533691, discriminator loss: 0.17743612136691808
# [INFO] Epoch 2/300, Batch 144/784 - generator loss: 9.08639316558838, discriminator loss: 0.08617794495075941
# [INFO] Epoch 2/300, Batch 149/784 - generator loss: 7.436175537109375, discriminator loss: 0.09388698786497116
# [INFO] Epoch 2/300, Batch 154/784 - generator loss: 6.862480354309082, discriminator loss: 0.2298626959323883
# [INFO] Epoch 2/300, Batch 159/784 - generator loss: 9.013138961791991, discriminator loss: 0.08522493988275529
# [INFO] Epoch 2/300, Batch 164/784 - generator loss: 6.11196928024292, discriminator loss: 0.039521390199661256
# [INFO] Epoch 2/300, Batch 169/784 - generator loss: 8.233657073974609, discriminator loss: 0.020986531488597394
# [INFO] Epoch 2/300, Batch 174/784 - generator loss: 6.138381481170654, discriminator loss: 0.031072053126990795
# [INFO] Epoch 2/300, Batch 179/784 - generator loss: 6.019559669494629, discriminator loss: 0.06762937158346176
# [INFO] Epoch 2/300, Batch 184/784 - generator loss: 7.556777667999268, discriminator loss: 0.13928849399089813
# [INFO] Epoch 2/300, Batch 189/784 - generator loss: 6.421967315673828, discriminator loss: 0.2759608291089535
# [INFO] Epoch 2/300, Batch 194/784 - generator loss: 8.335601997375488, discriminator loss: 0.18176673538982868
# [INFO] Epoch 2/300, Batch 199/784 - generator loss: 9.037522315979004, discriminator loss: 0.043066974729299545
# [INFO] Epoch 2/300, Batch 204/784 - generator loss: 8.5171067237854, discriminator loss: 0.07024910878390074
# [INFO] Epoch 2/300, Batch 209/784 - generator loss: 7.7054123878479, discriminator loss: 0.06663217060267926
# [INFO] Epoch 2/300, Batch 214/784 - generator loss: 7.08530216217041, discriminator loss: 0.07597343027591705
# [INFO] Epoch 2/300, Batch 219/784 - generator loss: 6.223752880096436, discriminator loss: 0.05972891077399254
# [INFO] Epoch 2/300, Batch 224/784 - generator loss: 7.260524749755859, discriminator loss: 0.11193548943847417
# [INFO] Epoch 2/300, Batch 229/784 - generator loss: 7.831879901885986, discriminator loss: 0.08041471764445304
# [INFO] Epoch 2/300, Batch 234/784 - generator loss: 7.902543735504151, discriminator loss: 0.028927092254161835
# [INFO] Epoch 2/300, Batch 239/784 - generator loss: 8.217793178558349, discriminator loss: 0.028174199908971787
# [INFO] Epoch 2/300, Batch 244/784 - generator loss: 7.024306297302246, discriminator loss: 0.07477115094661713
# [INFO] Epoch 2/300, Batch 249/784 - generator loss: 6.913000869750976, discriminator loss: 0.07962630242109299
# [INFO] Epoch 2/300, Batch 254/784 - generator loss: 6.974252223968506, discriminator loss: 0.045992852002382276
# [INFO] Epoch 2/300, Batch 259/784 - generator loss: 7.199139785766602, discriminator loss: 0.045125797390937805
# [INFO] Epoch 2/300, Batch 264/784 - generator loss: 6.205855464935302, discriminator loss: 0.06955198720097541
# [INFO] Epoch 2/300, Batch 269/784 - generator loss: 7.058001708984375, discriminator loss: 0.0492475776001811
# [INFO] Epoch 2/300, Batch 274/784 - generator loss: 8.573666763305663, discriminator loss: 0.026401924900710583
# [INFO] Epoch 2/300, Batch 279/784 - generator loss: 6.746286296844483, discriminator loss: 0.015882885828614236
# [INFO] Epoch 2/300, Batch 284/784 - generator loss: 6.786814880371094, discriminator loss: 0.03674529865384102
# [INFO] Epoch 2/300, Batch 289/784 - generator loss: 5.628613901138306, discriminator loss: 0.06614675261080265
# [INFO] Epoch 2/300, Batch 294/784 - generator loss: 8.273174285888672, discriminator loss: 0.04120201445184648
# [INFO] Epoch 2/300, Batch 299/784 - generator loss: 6.486909294128418, discriminator loss: 0.04707986041903496
# [INFO] Epoch 2/300, Batch 304/784 - generator loss: 6.441771507263184, discriminator loss: 0.04114478677511215
# [INFO] Epoch 2/300, Batch 309/784 - generator loss: 8.94317798614502, discriminator loss: 0.2798175457865
# [INFO] Epoch 2/300, Batch 314/784 - generator loss: 9.974553298950195, discriminator loss: 0.07810778678394854
# [INFO] Epoch 2/300, Batch 319/784 - generator loss: 8.719371509552001, discriminator loss: 0.06197767797857523
# [INFO] Epoch 2/300, Batch 324/784 - generator loss: 11.715766906738281, discriminator loss: 0.028734967089258136
# [INFO] Epoch 2/300, Batch 329/784 - generator loss: 7.197764301300049, discriminator loss: 0.09617121666669845
# [INFO] Epoch 2/300, Batch 334/784 - generator loss: 5.879301071166992, discriminator loss: 0.1244806170463562
# [INFO] Epoch 2/300, Batch 339/784 - generator loss: 6.554287433624268, discriminator loss: 0.022290557250380517
# [INFO] Epoch 2/300, Batch 344/784 - generator loss: 7.51865234375, discriminator loss: 0.017279593087732793
# [INFO] Epoch 2/300, Batch 349/784 - generator loss: 6.250818157196045, discriminator loss: 0.033844494819641115
# [INFO] Epoch 2/300, Batch 354/784 - generator loss: 6.47652530670166, discriminator loss: 0.175076699629426
# [INFO] Epoch 2/300, Batch 359/784 - generator loss: 7.8516332626342775, discriminator loss: 0.09213443621993064
# [INFO] Epoch 2/300, Batch 364/784 - generator loss: 9.832129192352294, discriminator loss: 0.04032208111602813
# [INFO] Epoch 2/300, Batch 369/784 - generator loss: 10.44323272705078, discriminator loss: 0.0257997922366485
# [INFO] Epoch 2/300, Batch 374/784 - generator loss: 6.291928672790528, discriminator loss: 0.03761191722005606
# [INFO] Epoch 2/300, Batch 379/784 - generator loss: 6.07470932006836, discriminator loss: 0.06398706175386906
# [INFO] Epoch 2/300, Batch 384/784 - generator loss: 6.77210431098938, discriminator loss: 0.19737937599420546
# [INFO] Epoch 2/300, Batch 389/784 - generator loss: 7.334988594055176, discriminator loss: 0.09426886737346649
# [INFO] Epoch 2/300, Batch 394/784 - generator loss: 9.71367130279541, discriminator loss: 0.07545097395777703
# [INFO] Epoch 2/300, Batch 399/784 - generator loss: 7.335474872589112, discriminator loss: 0.08256443738937377
# [INFO] Epoch 2/300, Batch 404/784 - generator loss: 7.949464988708496, discriminator loss: 0.056954794377088544
# [INFO] Epoch 2/300, Batch 409/784 - generator loss: 6.53286657333374, discriminator loss: 0.0232589241117239
# [INFO] Epoch 2/300, Batch 414/784 - generator loss: 5.638720226287842, discriminator loss: 0.04645846951752901
# [INFO] Epoch 2/300, Batch 419/784 - generator loss: 6.54738416671753, discriminator loss: 0.04418165571987629
# [INFO] Epoch 2/300, Batch 424/784 - generator loss: 6.446037483215332, discriminator loss: 0.036433083936572075
# [INFO] Epoch 2/300, Batch 429/784 - generator loss: 6.315112781524658, discriminator loss: 0.026813979260623455
# [INFO] Epoch 2/300, Batch 434/784 - generator loss: 6.575283622741699, discriminator loss: 0.03349355850368738
# [INFO] Epoch 2/300, Batch 439/784 - generator loss: 6.576987552642822, discriminator loss: 0.05104638673365116
# [INFO] Epoch 2/300, Batch 444/784 - generator loss: 8.948016166687012, discriminator loss: 0.029521365649998188
# [INFO] Epoch 2/300, Batch 449/784 - generator loss: 6.871457099914551, discriminator loss: 0.06634363234043121
# [INFO] Epoch 2/300, Batch 454/784 - generator loss: 9.900123691558838, discriminator loss: 0.09419750557281077
# [INFO] Epoch 2/300, Batch 459/784 - generator loss: 8.14903450012207, discriminator loss: 0.029051502235233784
# [INFO] Epoch 2/300, Batch 464/784 - generator loss: 11.662419700622559, discriminator loss: 0.02102346159517765
# [INFO] Epoch 2/300, Batch 469/784 - generator loss: 8.51503697251901, discriminator loss: 2.319214457087219
# [INFO] Epoch 2/300, Batch 474/784 - generator loss: 12.289336109161377, discriminator loss: 1.1436535905348137
# [INFO] Epoch 2/300, Batch 479/784 - generator loss: 7.002574253082275, discriminator loss: 0.606826252117753
# [INFO] Epoch 2/300, Batch 484/784 - generator loss: 11.889909362792968, discriminator loss: 0.3503011129796505
# [INFO] Epoch 2/300, Batch 489/784 - generator loss: 4.567933559417725, discriminator loss: 0.33316283822059634
# [INFO] Epoch 2/300, Batch 494/784 - generator loss: 5.912193393707275, discriminator loss: 0.2237665668129921
# [INFO] Epoch 2/300, Batch 499/784 - generator loss: 7.901140403747559, discriminator loss: 0.20978724360466003
# [INFO] Epoch 2/300, Batch 504/784 - generator loss: 4.868139362335205, discriminator loss: 0.15008004680275916
# [INFO] Epoch 2/300, Batch 509/784 - generator loss: 5.253449535369873, discriminator loss: 0.21025190651416778
# [INFO] Epoch 2/300, Batch 514/784 - generator loss: 4.207110738754272, discriminator loss: 0.21189267039299012
# [INFO] Epoch 2/300, Batch 519/784 - generator loss: 4.950974464416504, discriminator loss: 0.14210325181484224
# [INFO] Epoch 2/300, Batch 524/784 - generator loss: 4.291676712036133, discriminator loss: 0.22189073860645295
# [INFO] Epoch 2/300, Batch 529/784 - generator loss: 4.998759078979492, discriminator loss: 0.13061440885066986
# [INFO] Epoch 2/300, Batch 534/784 - generator loss: 4.426708698272705, discriminator loss: 0.1869622953236103
# [INFO] Epoch 2/300, Batch 539/784 - generator loss: 5.373720264434814, discriminator loss: 0.10440118387341499
# [INFO] Epoch 2/300, Batch 544/784 - generator loss: 5.022834300994873, discriminator loss: 0.14000887125730516
# [INFO] Epoch 2/300, Batch 549/784 - generator loss: 4.741808533668518, discriminator loss: 0.5552195340394974
# [INFO] Epoch 2/300, Batch 554/784 - generator loss: 8.338212394714356, discriminator loss: 0.13960074484348298
# [INFO] Epoch 2/300, Batch 559/784 - generator loss: 5.537594223022461, discriminator loss: 0.17546309903264046
# [INFO] Epoch 2/300, Batch 564/784 - generator loss: 6.802144622802734, discriminator loss: 0.06262719817459583
# [INFO] Epoch 2/300, Batch 569/784 - generator loss: 7.422684001922607, discriminator loss: 0.05327762700617313
# [INFO] Epoch 2/300, Batch 574/784 - generator loss: 5.032614707946777, discriminator loss: 0.05681748613715172
# [INFO] Epoch 2/300, Batch 579/784 - generator loss: 4.35743465423584, discriminator loss: 0.1371140405535698
# [INFO] Epoch 2/300, Batch 584/784 - generator loss: 5.479757785797119, discriminator loss: 0.05516213104128838
# ...
# [INFO] Epoch 29/300, Batch 289/784 - generator loss: 9.595761394500732, discriminator loss: 0.2119126223027706
# [INFO] Epoch 29/300, Batch 294/784 - generator loss: 7.390499424934387, discriminator loss: 0.15924179228022695
# [INFO] Epoch 29/300, Batch 299/784 - generator loss: 14.170798873901367, discriminator loss: 0.08661448881030083
# [INFO] Epoch 29/300, Batch 304/784 - generator loss: 7.401900100708008, discriminator loss: 0.07204838814213872
# [INFO] Epoch 29/300, Batch 309/784 - generator loss: 10.441147994995116, discriminator loss: 0.05030200453475118
# [INFO] Epoch 29/300, Batch 314/784 - generator loss: 5.617691898345948, discriminator loss: 0.06182606667280197
# [INFO] Epoch 29/300, Batch 319/784 - generator loss: 7.855970954895019, discriminator loss: 0.06235430836677551
# [INFO] Epoch 29/300, Batch 324/784 - generator loss: 7.266919326782227, discriminator loss: 0.14438251927495002
# [INFO] Epoch 29/300, Batch 329/784 - generator loss: 4.908873128890991, discriminator loss: 0.12560600116848947
# [INFO] Epoch 29/300, Batch 334/784 - generator loss: 10.79666976928711, discriminator loss: 0.08459687158465386
# [INFO] Epoch 29/300, Batch 339/784 - generator loss: 6.971889495849609, discriminator loss: 0.1065863786265254
# [INFO] Epoch 29/300, Batch 344/784 - generator loss: 7.545701718330383, discriminator loss: 0.7948830589652062
# [INFO] Epoch 29/300, Batch 349/784 - generator loss: 16.753383827209472, discriminator loss: 0.16970355701632797
# [INFO] Epoch 29/300, Batch 354/784 - generator loss: 6.167328405380249, discriminator loss: 0.14640760023612528
# [INFO] Epoch 29/300, Batch 359/784 - generator loss: 18.124934959411622, discriminator loss: 0.02017460874048993
# [INFO] Epoch 29/300, Batch 364/784 - generator loss: 11.29534616470337, discriminator loss: 0.18576601929962636
# [INFO] Epoch 29/300, Batch 369/784 - generator loss: 9.007294988632202, discriminator loss: 0.16977185793220997
# [INFO] Epoch 29/300, Batch 374/784 - generator loss: 14.416627883911133, discriminator loss: 0.09133422281593084
# [INFO] Epoch 29/300, Batch 379/784 - generator loss: 8.70487470626831, discriminator loss: 0.026778719201684
# [INFO] Epoch 29/300, Batch 384/784 - generator loss: 8.377833652496339, discriminator loss: 0.21624938398599625
# [INFO] Epoch 29/300, Batch 389/784 - generator loss: 6.422138786315918, discriminator loss: 0.1521218091249466
# [INFO] Epoch 29/300, Batch 394/784 - generator loss: 7.68514461517334, discriminator loss: 0.11268258839845657
# [INFO] Epoch 29/300, Batch 399/784 - generator loss: 8.965559387207032, discriminator loss: 0.08913465794175864
# [INFO] Epoch 29/300, Batch 404/784 - generator loss: 7.1525012969970705, discriminator loss: 0.040377413108944896
# [INFO] Epoch 29/300, Batch 409/784 - generator loss: 7.287587451934814, discriminator loss: 0.07924136035144329
# [INFO] Epoch 29/300, Batch 414/784 - generator loss: 6.431179809570312, discriminator loss: 0.0607417332008481
# [INFO] Epoch 29/300, Batch 419/784 - generator loss: 7.474892520904541, discriminator loss: 0.061920403689146045
# [INFO] Epoch 29/300, Batch 424/784 - generator loss: 7.251406288146972, discriminator loss: 0.08247398510575295
# [INFO] Epoch 29/300, Batch 429/784 - generator loss: 4.971392822265625, discriminator loss: 0.08189418092370034
# [INFO] Epoch 29/300, Batch 434/784 - generator loss: 7.1100719451904295, discriminator loss: 0.12977390065789224
# [INFO] Epoch 29/300, Batch 439/784 - generator loss: 8.306166744232177, discriminator loss: 0.08024307377636433
# [INFO] Epoch 29/300, Batch 444/784 - generator loss: 6.389808940887451, discriminator loss: 0.04625124931335449
# [INFO] Epoch 29/300, Batch 449/784 - generator loss: 8.267957210540771, discriminator loss: 0.057192495465278624
# [INFO] Epoch 29/300, Batch 454/784 - generator loss: 6.643998718261718, discriminator loss: 0.05745417177677155
# [INFO] Epoch 29/300, Batch 459/784 - generator loss: 6.338509559631348, discriminator loss: 0.1117561176419258
# [INFO] Epoch 29/300, Batch 464/784 - generator loss: 7.0538629531860355, discriminator loss: 0.0607204919680953
# [INFO] Epoch 29/300, Batch 469/784 - generator loss: 6.499039936065674, discriminator loss: 0.04492419585585594
# [INFO] Epoch 29/300, Batch 474/784 - generator loss: 7.0791065216064455, discriminator loss: 0.06016641892492771
# [INFO] Epoch 29/300, Batch 479/784 - generator loss: 6.787157344818115, discriminator loss: 0.06585972607135773
# [INFO] Epoch 29/300, Batch 484/784 - generator loss: 6.350572109222412, discriminator loss: 0.07438086718320847
# [INFO] Epoch 29/300, Batch 489/784 - generator loss: 6.922740650177002, discriminator loss: 0.06005018837749958
# [INFO] Epoch 29/300, Batch 494/784 - generator loss: 8.103144359588622, discriminator loss: 0.10166297480463982
# [INFO] Epoch 29/300, Batch 499/784 - generator loss: 5.885251140594482, discriminator loss: 0.08079248834401369
# [INFO] Epoch 29/300, Batch 504/784 - generator loss: 7.652532863616943, discriminator loss: 0.06945790257304907
# [INFO] Epoch 29/300, Batch 509/784 - generator loss: 6.09730863571167, discriminator loss: 0.06418660804629325
# [INFO] Epoch 29/300, Batch 514/784 - generator loss: 9.228278350830077, discriminator loss: 0.018576809763908388
# [INFO] Epoch 29/300, Batch 519/784 - generator loss: 7.387189865112305, discriminator loss: 0.029956943169236184
# [INFO] Epoch 29/300, Batch 524/784 - generator loss: 6.695318984985351, discriminator loss: 0.06974689103662968
# [INFO] Epoch 29/300, Batch 529/784 - generator loss: 7.801154708862304, discriminator loss: 0.055707842111587524
# [INFO] Epoch 29/300, Batch 534/784 - generator loss: 8.726076889038087, discriminator loss: 0.04018888156861067
# [INFO] Epoch 29/300, Batch 539/784 - generator loss: 6.492154693603515, discriminator loss: 0.035689618438482285
# [INFO] Epoch 29/300, Batch 544/784 - generator loss: 7.505099296569824, discriminator loss: 0.027312066592276096
# [INFO] Epoch 29/300, Batch 549/784 - generator loss: 6.979825019836426, discriminator loss: 0.04140764996409416
# [INFO] Epoch 29/300, Batch 554/784 - generator loss: 6.311202430725098, discriminator loss: 0.11351729780435563
# [INFO] Epoch 29/300, Batch 559/784 - generator loss: 10.457442665100098, discriminator loss: 0.07541360724717379
# [INFO] Epoch 29/300, Batch 564/784 - generator loss: 7.355807304382324, discriminator loss: 0.025086544826626776
# [INFO] Epoch 29/300, Batch 569/784 - generator loss: 8.371552467346191, discriminator loss: 0.028697483241558075
# [INFO] Epoch 29/300, Batch 574/784 - generator loss: 6.025872135162354, discriminator loss: 0.034427945874631403
# [INFO] Epoch 29/300, Batch 579/784 - generator loss: 6.859238243103027, discriminator loss: 0.03975321166217327
# [INFO] Epoch 29/300, Batch 584/784 - generator loss: 5.662316131591797, discriminator loss: 0.03302709497511387
# [INFO] Epoch 29/300, Batch 589/784 - generator loss: 5.671274948120117, discriminator loss: 0.17157945185899734
# [INFO] Epoch 29/300, Batch 594/784 - generator loss: 6.322746849060058, discriminator loss: 0.05144117437303066
# [INFO] Epoch 29/300, Batch 599/784 - generator loss: 6.999045181274414, discriminator loss: 0.027807160280644894
# [INFO] Epoch 29/300, Batch 604/784 - generator loss: 7.0518135070800785, discriminator loss: 0.023080139048397542
# [INFO] Epoch 29/300, Batch 609/784 - generator loss: 6.723580741882325, discriminator loss: 0.056166397966444494
# [INFO] Epoch 29/300, Batch 614/784 - generator loss: 5.3456954002380375, discriminator loss: 0.10985233336687088
# [INFO] Epoch 29/300, Batch 619/784 - generator loss: 6.129161930084228, discriminator loss: 0.14293466433882712
# [INFO] Epoch 29/300, Batch 624/784 - generator loss: 7.448662662506104, discriminator loss: 0.0957039755769074
# [INFO] Epoch 29/300, Batch 629/784 - generator loss: 8.05341386795044, discriminator loss: 0.09433906581252813
# [INFO] Epoch 29/300, Batch 634/784 - generator loss: 6.2001372337341305, discriminator loss: 0.02168944012373686
# [INFO] Epoch 29/300, Batch 639/784 - generator loss: 8.82232837677002, discriminator loss: 0.08986962363123893
# [INFO] Epoch 29/300, Batch 644/784 - generator loss: 6.490998888015747, discriminator loss: 0.11679990924894809
# [INFO] Epoch 29/300, Batch 649/784 - generator loss: 6.38330659866333, discriminator loss: 0.2011990997940302
# [INFO] Epoch 29/300, Batch 654/784 - generator loss: 9.082240772247314, discriminator loss: 0.1884008426219225
# [INFO] Epoch 29/300, Batch 659/784 - generator loss: 12.977267169952393, discriminator loss: 0.22955851275473832
# [INFO] Epoch 29/300, Batch 664/784 - generator loss: 11.10064239501953, discriminator loss: 0.0601302295923233
# [INFO] Epoch 29/300, Batch 669/784 - generator loss: 6.948457527160644, discriminator loss: 0.031154626794159413
# [INFO] Epoch 29/300, Batch 674/784 - generator loss: 11.978003692626952, discriminator loss: 0.13789679557085038
# [INFO] Epoch 29/300, Batch 679/784 - generator loss: 6.335844278335571, discriminator loss: 0.09178426843136549
# [INFO] Epoch 29/300, Batch 684/784 - generator loss: 9.865727710723878, discriminator loss: 0.07427995502948762
# [INFO] Epoch 29/300, Batch 689/784 - generator loss: 6.485660362243652, discriminator loss: 0.05382412299513817
# [INFO] Epoch 29/300, Batch 694/784 - generator loss: 7.0582856178283695, discriminator loss: 0.09451052770018578
# [INFO] Epoch 29/300, Batch 699/784 - generator loss: 5.834895229339599, discriminator loss: 0.07967016398906708
# [INFO] Epoch 29/300, Batch 704/784 - generator loss: 5.957446765899658, discriminator loss: 0.06584690064191819
# [INFO] Epoch 29/300, Batch 709/784 - generator loss: 6.784361839294434, discriminator loss: 0.08189093247056008
# [INFO] Epoch 29/300, Batch 714/784 - generator loss: 5.643258094787598, discriminator loss: 0.17343188524246217
# [INFO] Epoch 29/300, Batch 719/784 - generator loss: 11.725146198272705, discriminator loss: 0.09507469199597836
# [INFO] Epoch 29/300, Batch 724/784 - generator loss: 6.060855197906494, discriminator loss: 0.0651335242204368
# [INFO] Epoch 29/300, Batch 729/784 - generator loss: 11.544500350952148, discriminator loss: 0.025114243477582933
# [INFO] Epoch 29/300, Batch 734/784 - generator loss: 7.092331409454346, discriminator loss: 0.041521033830940725
# [INFO] Epoch 29/300, Batch 739/784 - generator loss: 6.304897212982178, discriminator loss: 0.06924707368016243
# [INFO] Epoch 29/300, Batch 744/784 - generator loss: 6.371195125579834, discriminator loss: 0.06672420874238014
# [INFO] Epoch 29/300, Batch 749/784 - generator loss: 7.464407539367675, discriminator loss: 0.058301239460706714
# [INFO] Epoch 29/300, Batch 754/784 - generator loss: 5.962857437133789, discriminator loss: 0.055914928764104845
# [INFO] Epoch 29/300, Batch 759/784 - generator loss: 4.674330329895019, discriminator loss: 0.07002182006835937
# [INFO] Epoch 29/300, Batch 764/784 - generator loss: 6.443984317779541, discriminator loss: 0.14171747267246246
# [INFO] Epoch 29/300, Batch 769/784 - generator loss: 8.769672107696532, discriminator loss: 0.03481654860079288
# [INFO] Epoch 29/300, Batch 774/784 - generator loss: 7.7204132080078125, discriminator loss: 0.04580859057605267
# [INFO] Epoch 29/300, Batch 779/784 - generator loss: 8.053302001953124, discriminator loss: 0.04595013069920242
# [INFO] Saving samples...
# [INFO] Saving checkpoints...
# [INFO] Epoch 30/300, Batch 4/784 - generator loss: 6.4882307052612305, discriminator loss: 0.03963276878413227
# [INFO] Epoch 30/300, Batch 9/784 - generator loss: 6.524197196960449, discriminator loss: 0.08337540291249752
# [INFO] Epoch 30/300, Batch 14/784 - generator loss: 6.650404739379883, discriminator loss: 0.05387778915464878
# [INFO] Epoch 30/300, Batch 19/784 - generator loss: 6.074416923522949, discriminator loss: 0.09393198043107986
# [INFO] Epoch 30/300, Batch 24/784 - generator loss: 8.82667818069458, discriminator loss: 0.10735058635473252
# [INFO] Epoch 30/300, Batch 29/784 - generator loss: 6.7380167007446286, discriminator loss: 0.06076453626155853
# [INFO] Epoch 30/300, Batch 34/784 - generator loss: 11.93083553314209, discriminator loss: 0.08463606797158718
# [INFO] Epoch 30/300, Batch 39/784 - generator loss: 8.027138042449952, discriminator loss: 0.10844745300710201
# [INFO] Epoch 30/300, Batch 44/784 - generator loss: 13.115722465515137, discriminator loss: 0.05289106350392103
# [INFO] Epoch 30/300, Batch 49/784 - generator loss: 6.365603637695313, discriminator loss: 0.04033371666446328
# [INFO] Epoch 30/300, Batch 54/784 - generator loss: 9.276367092132569, discriminator loss: 0.023127950821071865
# [INFO] Epoch 30/300, Batch 59/784 - generator loss: 6.557247543334961, discriminator loss: 0.053998588025569914
# [INFO] Epoch 30/300, Batch 64/784 - generator loss: 7.754158401489258, discriminator loss: 0.09415703266859055
# [INFO] Epoch 30/300, Batch 69/784 - generator loss: 7.230996894836426, discriminator loss: 0.06155699267983437
# [INFO] Epoch 30/300, Batch 74/784 - generator loss: 7.048884296417237, discriminator loss: 0.019276868924498557
# [INFO] Epoch 30/300, Batch 79/784 - generator loss: 5.939698314666748, discriminator loss: 0.042347579076886174
# [INFO] Epoch 30/300, Batch 84/784 - generator loss: 6.982912826538086, discriminator loss: 0.07118726521730423
# [INFO] Epoch 30/300, Batch 89/784 - generator loss: 5.703276252746582, discriminator loss: 0.0971786379814148
# [INFO] Epoch 30/300, Batch 94/784 - generator loss: 6.378544425964355, discriminator loss: 0.07796922214329242
# [INFO] Epoch 30/300, Batch 99/784 - generator loss: 5.6589302062988285, discriminator loss: 0.13923646956682206
# [INFO] Epoch 30/300, Batch 104/784 - generator loss: 7.705131721496582, discriminator loss: 0.04829274732619524
# [INFO] Epoch 30/300, Batch 109/784 - generator loss: 6.0728678703308105, discriminator loss: 0.0422075804322958
# [INFO] Epoch 30/300, Batch 114/784 - generator loss: 6.915963077545166, discriminator loss: 0.05004377737641334
# [INFO] Epoch 30/300, Batch 119/784 - generator loss: 6.452807378768921, discriminator loss: 0.18535640686750413
# [INFO] Epoch 30/300, Batch 124/784 - generator loss: 6.350173282623291, discriminator loss: 0.11470934264361858
# [INFO] Epoch 30/300, Batch 129/784 - generator loss: 10.676413536071777, discriminator loss: 0.09850719384849072
# [INFO] Epoch 30/300, Batch 134/784 - generator loss: 7.670011520385742, discriminator loss: 0.1110687579959631
# [INFO] Epoch 30/300, Batch 139/784 - generator loss: 10.582846069335938, discriminator loss: 0.06256332099437714
# [INFO] Epoch 30/300, Batch 144/784 - generator loss: 8.615854740142822, discriminator loss: 0.15237716771662235
# [INFO] Epoch 30/300, Batch 149/784 - generator loss: 6.938640928268432, discriminator loss: 0.2139279406517744
# [INFO] Epoch 30/300, Batch 154/784 - generator loss: 12.458267784118652, discriminator loss: 0.06331457546912134
# [INFO] Epoch 30/300, Batch 159/784 - generator loss: 6.642656898498535, discriminator loss: 0.028541099280118942
# [INFO] Epoch 30/300, Batch 164/784 - generator loss: 8.625312232971192, discriminator loss: 0.03577863089740276
# [INFO] Epoch 30/300, Batch 169/784 - generator loss: 6.63000898361206, discriminator loss: 0.11634519957005977
# [INFO] Epoch 30/300, Batch 174/784 - generator loss: 7.126117324829101, discriminator loss: 0.05847588405013084
# [INFO] Epoch 30/300, Batch 179/784 - generator loss: 5.72887077331543, discriminator loss: 0.09236429631710052
# [INFO] Epoch 30/300, Batch 184/784 - generator loss: 6.806271743774414, discriminator loss: 0.08643086031079292
# [INFO] Epoch 30/300, Batch 189/784 - generator loss: 6.079215002059937, discriminator loss: 0.23471058309078216
# [INFO] Epoch 30/300, Batch 194/784 - generator loss: 10.80725326538086, discriminator loss: 0.10050615761429071
# [INFO] Epoch 30/300, Batch 199/784 - generator loss: 7.6039834976196286, discriminator loss: 0.07037045918405056
# [INFO] Epoch 30/300, Batch 204/784 - generator loss: 9.489181327819825, discriminator loss: 0.041397384740412234
# [INFO] Epoch 30/300, Batch 209/784 - generator loss: 6.700872802734375, discriminator loss: 0.07390133664011955
# [INFO] Epoch 30/300, Batch 214/784 - generator loss: 6.7092053413391115, discriminator loss: 0.07090323120355606
